# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('all_working_domains.csv')
urls = df['0']
urls[:5]
# Out:
# 0    https://1000sotok.ru
# 1         https://10rg.ru
# 2      https://12sever.ru
# 3     https://1470umto.ru
# 4        https://1lion.ru
# Name: 0, dtype: object

# %%
PHONE_PATTERNS = [
    r'\(\d{4}\) \d{3}-\d{3}',
    r'\(\d{4}\) \d{2}-\d{2}-\d{2}',
    
    # 1 3 3 (2 2 | 4)
    r'\(?\+?[78][\s-]\(?\d{3}\)?[\s-]?\d{3}[\s-]?\d{2}[\s-]?\d{2}',

    # 1|0 4 2 (2 2 | 4)
    r'\+\d?[\s-]?\(?\d{4}\)?[\s-]\d{2}[\s-]\d{2}[\s-]?\d{2}',
]

possible_subpages = ['about', 'contacts', 'Контакты', 'О компании', 'company', 'kompaniya', 'o-komanii', 'contact']

# %%
from bs4 import BeautifulSoup as bs
import requests
import re

def find_inn(s):
    ans = re.findall(r'[^a-zA-Z0-9\'\"\?\!]\d{10}[^a-zA-Z0-9\'\"\?\!]', s)
    if ans:
        ans = [e.strip() for e in ans]
        return ans
    else:
        return None

def find_ogrn(s):
    ans = tuple(re.findall(r'[^a-zA-Z0-9\'\"\?\!]\d{13}[^a-zA-Z0-9\'\"\?\!]', s))
    if ans:
        ans = [e.strip() for e in ans]
        return ans
    else:
        return None

# %%
def extract_address(s):
    pattern = r'\г\.?\s[А-Я][а-я]+.*'
    ans = list(re.findall(pattern, s))
    if ans:
        return list([e.split()[:10] for e in re.findall(pattern, s)])
    else:
        return []

extract_address('Московская область, г. Домодедово, Каширское шоссе, 7, Кабинеты 405(А), 405(Б)')
# Out:
# [['г.',
#   'Домодедово,',
#   'Каширское',
#   'шоссе,',
#   '7,',
#   'Кабинеты',
#   '405(А),',
#   '405(Б)']]

# %%
def extract_mail(line):
    match = re.search(r'[\w.+-]+@[\w-]+\.[\w.-]+', line)
    return match.group(0)

def get_phone_numbers(line):
    global PHONE_PATTERNS
    for pattern in PHONE_PATTERNS:
        if len(re.findall(pattern, line)) > 0:
            return np.unique(re.findall(pattern, line))
        
def get_mails(text):
    if '@' in text:
        try:
            return extract_mail(text)
        except:
            pass
        
def standart_phone(t):
    if t != None:
        res = []
        for p in t:
            r = ''
            for c in p:
                if c.isdigit():
                    r+=c
            res.append(r) 
        return np.unique(res)
    else:
        return None
        
urls = pd.read_csv('all_working_domains.csv', header=None)
urls = urls[urls.columns[0]]
urls = urls[1:]

# %%
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

def parse_one_url(url):
    
    session = requests.Session()
    retry = Retry(connect=2, backoff_factor=0)
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    try:
        req = session.get(url)
        soup = bs(req.text, 'html.parser')
        texts = soup.find_all(text=True)
        texts = u" ".join(t.strip() for t in texts)
        l = [url,  get_phone_numbers(texts), get_mails(texts), find_inn(texts), find_ogrn(texts), extract_address(texts)]
        global possible_subpages
        for sub in possible_subpages:
                r = session.get(url)
                soup = bs(r.text, 'html.parser')
                ts = soup.find_all(text=True)
                ts = u" ".join(t.strip() for t in ts)
                if len(l[1]) < 1:
                    l[1] = get_phone_numbers(ts)
                if l[2] == None:
                    l[2] = get_mails(ts)
            
                if not l[3]:
                    l[3] = find_inn(ts)
                    if not l[4]:
                        l[4] = find_ogrn(ts)
                    
                l[5].append(extract_address(ts))
                l[1] = np.unique([''.join(re.findall(r'\d+', e)) for e in l[1]])
        return l
    except:
        return [None for _ in range(6)]

# %%
parse_one_url('https://kraszem.ru')
# Out:
# ['https://kraszem.ru',
#  array(['74957252603', '74959692929'], dtype='<U11'),
#  'info@kraszem.ru',
#  None,
#  ['_1676460961150{', '_1676460961150:'],
#  [['г.',
#    'Москва,',
#    'пр-т',
#    'Андропова,',
#    'д.',
#    '22,',
#    '16',
#    'этаж',
#    'info@kraszem.ru',
#    'Оставить'],
#   [['г.',
#     'Москва,',
#     'пр-т',
#     'Андропова,',
#     'д.',
#     '22,',
#     '16',
#     'этаж',
#     'info@kraszem.ru',
#     'Оставить']],
#   [['г.',
#     'Москва,',
#     'пр-т',
#     'Андропова,',
#     'д.',
#     '22,',
#     '16',
#     'этаж',
#     'info@kraszem.ru',
#     'Оставить']],
#   [['г.',
#     'Москва,',
#     'пр-т',
#     'Андропова,',
#     'д.',
#     '22,',
#     '16',
#     'этаж',
#     'info@kraszem.ru',
#     'Оставить']],
#   [['г.',
#     'Москва,',
#     'пр-т',
#     'Андропова,',
#     'д.',
#     '22,',
#     '16',
#     'этаж',
#     'info@kraszem.ru',
#     'Оставить']],
#   [['г.',
#     'Москва,',
#     'пр-т',
#     'Андропова,',
#     'д.',
#     '22,',
#     '16',
#     'этаж',
#     'info@kraszem.ru',
#     'Оставить']],
#   [['г.',
#     'Москва,',
#     'пр-т',
#     'Андропова,',
#     'д.',
#     '22,',
#     '16',
#     'этаж',
#     'info@kraszem.ru',
#     'Оставить']],
#   [['г.',
#     'Москва,',
#     'пр-т',
#     'Андропова,',
#     'д.',
#     '22,',
#     '16',
#     'этаж',
#     'info@kraszem.ru',
#     'Оставить']],
#   [['г.',
#     'Москва,',
#     'пр-т',
#     'Андропова,',
#     'д.',
#     '22,',
#     '16',
#     'этаж',
#     'info@kraszem.ru',
#     'Оставить']]]]

# %%
from p_tqdm import p_map

num_cpus = 16

results = p_map(parse_one_url, urls[:100], **{"num_cpus": num_cpus})
# Out:
# 100%|██████████| 100/100 [00:57<00:00,  1.74it/s]

# %%
results
# Out:
# [['https://1000sotok.ru',
#   array(['88125150070', '89013021152', '89013021312', '89013038264',
#          '89013052188', '89013075315'], dtype='<U11'),
#   None,
#   None,
#   None,
#   [[], [], [], [], [], [], [], []]],
#  [None, None, None, None, None, None],
#  ['https://12sever.ru',
#   array(['8362335588', '8362458854'], dtype='<U10'),
#   'seversg@bk.ru',
#   ['1681765606', '1681765606', '1681765606'],
#   ['_1535552722157{',
#    '_1538396594893{',
#    '_1490364209546{',
#    '_1532518586805{',
#    '_1530521315572{',
#    '_1530521407191{',
#    '_1530521464885{',
#    '_1536305760231{'],
#   [['г.',
#     'Йошкар-Ола,',
#     'ул.',
#     'Чернякова,',
#     'поз.',
#     '25',
#     '(1',
#     'этап',
#     'строительства)',
#     'Объект:'],
#    [['г.',
#      'Йошкар-Ола,',
#      'ул.',
#      'Чернякова,',
#      'поз.',
#      '25',
#      '(1',
#      'этап',
#      'строительства)',
#      'Объект:']],
#    [['г.',
#      'Йошкар-Ола,',
#      'ул.',
#      'Чернякова,',
#      'поз.',
#      '25',
#      '(1',
#      'этап',
#      'строительства)',
#      'Объект:']],
#    [['г.',
#      'Йошкар-Ола,',
#      'ул.',
#      'Чернякова,',
#      'поз.',
#      '25',
#      '(1',
#      'этап',
#      'строительства)',
#      'Объект:']],
#    [['г.',
#      'Йошкар-Ола,',
#      'ул.',
#      'Чернякова,',
#      'поз.',
#      '25',
#      '(1',
#      'этап',
#      'строительства)',
#      'Объект:']],
#    [['г.',
#      'Йошкар-Ола,',
#      'ул.',
#      'Чернякова,',
#      'поз.',
#      '25',
#      '(1',
#      'этап',
#      'строительства)',
#      'Объект:']],
#    [['г.',
#      'Йошкар-Ола,',
#      'ул.',
#      'Чернякова,',
#      'поз.',
#      '25',
#      '(1',
#      'этап',
#      'строительства)',
#      'Объект:']],
#    [['г.',
#      'Йошкар-Ола,',
#      'ул.',
#      'Чернякова,',
#      'поз.',
#      '25',
#      '(1',
#      'этап',
#      'строительства)',
#      'Объект:']],
#    [['г.',
#      'Йошкар-Ола,',
#      'ул.',
#      'Чернякова,',
#      'поз.',
#      '25',
#      '(1',
#      'этап',
#      'строительства)',
#      'Объект:']]]],
#  ['https://1470umto.ru',
#   array(['3022217719'], dtype='<U10'),
#   'info@1470umto.ru',
#   None,
#   None,
#   [['г.', 'Москва,', 'Очаковское', 'шоссе,', 'д.', '28', "с.1';"],
#    ['г.', 'Москва,', 'ул.', 'Искры,', 'д.', "33';"],
#    ['г.', 'Москва,', 'ул.', 'Тушинская,', 'д.', "24';"],
#    ['г.', 'Ростов-на-Дону,', 'пер.', 'Нефтяной,', '4', "“A”';"],
#    ['г.', 'Чита,', 'ул.', 'Трактовая,', 'вл.3,', "стр.29';"],
#    ['г.', 'Самара,', 'ул.', 'Товарная,', "д.25';"],
#    ['г.', 'Екатеринбург,', 'ул.', 'Маневровая', '34', "“A”';"],
#    ['г.', 'Хабаровск,', 'пер.', 'Каширский,', "д.1';"],
#    ['г.', 'Энгельс,', 'ул.', 'Тракторная,', "д.1';"],
#    ['г.', 'Гатчина,', 'ул.', 'Жемчужина,', 'д.', "5';"],
#    ['г.', 'Костерево,', 'ул.', "Заречная';"],
#    ['г.', 'Мурманск,', 'ул.', 'Нижне-Ростинское', "шоссе28';"],
#    ['г.', 'Вязьма,', 'ул.', 'Песочная,', "2';"],
#    ['г.', 'Владивосток,', 'ул.', 'Фадеева,', 'д.', "42';"],
#    ['г.',
#     'Москва,',
#     'Очаковское',
#     'шоссе,',
#     'д.',
#     '28',
#     'с.1',
#     '119530,',
#     'г.',
#     'Москва,'],
#    ['г.',
#     'Москве,',
#     'г.',
#     'Лобне',
#     'Московской',
#     'области,',
#     'п.',
#     'Калининец',
#     'Московской',
#     'области,'],
#    ['г.',
#     'Москва,',
#     'Московская',
#     'область,',
#     'г.',
#     'Самара,',
#     'г.',
#     'Ростов-на-Дону,',
#     'г.',
#     'Екатеринбург,'],
#    ['г.',
#     'Москва,',
#     '34',
#     'ПК',
#     'г.',
#     'Москва,',
#     'ОБЛ-Спецтранс',
#     'МО,',
#     'г.',
#     'ЛОБНЯ,'],
#    [['г.', 'Москва,', 'Очаковское', 'шоссе,', 'д.', '28', "с.1';"],
#     ['г.', 'Москва,', 'ул.', 'Искры,', 'д.', "33';"],
#     ['г.', 'Москва,', 'ул.', 'Тушинская,', 'д.', "24';"],
#     ['г.', 'Ростов-на-Дону,', 'пер.', 'Нефтяной,', '4', "“A”';"],
#     ['г.', 'Чита,', 'ул.', 'Трактовая,', 'вл.3,', "стр.29';"],
#     ['г.', 'Самара,', 'ул.', 'Товарная,', "д.25';"],
#     ['г.', 'Екатеринбург,', 'ул.', 'Маневровая', '34', "“A”';"],
#     ['г.', 'Хабаровск,', 'пер.', 'Каширский,', "д.1';"],
#     ['г.', 'Энгельс,', 'ул.', 'Тракторная,', "д.1';"],
#     ['г.', 'Гатчина,', 'ул.', 'Жемчужина,', 'д.', "5';"],
#     ['г.', 'Костерево,', 'ул.', "Заречная';"],
#     ['г.', 'Мурманск,', 'ул.', 'Нижне-Ростинское', "шоссе28';"],
#     ['г.', 'Вязьма,', 'ул.', 'Песочная,', "2';"],
#     ['г.', 'Владивосток,', 'ул.', 'Фадеева,', 'д.', "42';"],
#     ['г.',
#      'Москва,',
#      'Очаковское',
#      'шоссе,',
#      'д.',
#      '28',
#      'с.1',
#      '119530,',
#      'г.',
#      'Москва,'],
#     ['г.',
#      'Москве,',
#      'г.',
#      'Лобне',
#      'Московской',
#      'области,',
#      'п.',
#      'Калининец',
#      'Московской',
#      'области,'],
#     ['г.',
#      'Москва,',
#      'Московская',
#      'область,',
#      'г.',
#      'Самара,',
#      'г.',
#      'Ростов-на-Дону,',
#      'г.',
#      'Екатеринбург,'],
#     ['г.',
#      'Москва,',
#      '34',
#      'ПК',
#      'г.',
#      'Москва,',
#      'ОБЛ-Спецтранс',
#      'МО,',
#      'г.',
#      'ЛОБНЯ,']],
#    [['г.', 'Москва,', 'Очаковское', 'шоссе,', 'д.', '28', "с.1';"],
#     ['г.', 'Москва,', 'ул.', 'Искры,', 'д.', "33';"],
#     ['г.', 'Москва,', 'ул.', 'Тушинская,', 'д.', "24';"],
#     ['г.', 'Ростов-на-Дону,', 'пер.', 'Нефтяной,', '4', "“A”';"],
#     ['г.', 'Чита,', 'ул.', 'Трактовая,', 'вл.3,', "стр.29';"],
#     ['г.', 'Самара,', 'ул.', 'Товарная,', "д.25';"],
#     ['г.', 'Екатеринбург,', 'ул.', 'Маневровая', '34', "“A”';"],
#     ['г.', 'Хабаровск,', 'пер.', 'Каширский,', "д.1';"],
#     ['г.', 'Энгельс,', 'ул.', 'Тракторная,', "д.1';"],
#     ['г.', 'Гатчина,', 'ул.', 'Жемчужина,', 'д.', "5';"],
#     ['г.', 'Костерево,', 'ул.', "Заречная';"],
#     ['г.', 'Мурманск,', 'ул.', 'Нижне-Ростинское', "шоссе28';"],
#     ['г.', 'Вязьма,', 'ул.', 'Песочная,', "2';"],
#     ['г.', 'Владивосток,', 'ул.', 'Фадеева,', 'д.', "42';"],
#     ['г.',
#      'Москва,',
#      'Очаковское',
#      'шоссе,',
#      'д.',
#      '28',
#      'с.1',
#      '119530,',
#      'г.',
#      'Москва,'],
#     ['г.',
#      'Москве,',
#      'г.',
#      'Лобне',
#      'Московской',
#      'области,',
#      'п.',
#      'Калининец',
#      'Московской',
#      'области,'],
#     ['г.',
#      'Москва,',
#      'Московская',
#      'область,',
#      'г.',
#      'Самара,',
#      'г.',
#      'Ростов-на-Дону,',
#      'г.',
#      'Екатеринбург,'],
#     ['г.',
#      'Москва,',
#      '34',
#      'ПК',
#      'г.',
#      'Москва,',
#      'ОБЛ-Спецтранс',
#      'МО,',
#      'г.',
#      'ЛОБНЯ,']],
#    [['г.', 'Москва,', 'Очаковское', 'шоссе,', 'д.', '28', "с.1';"],
#     ['г.', 'Москва,', 'ул.', 'Искры,', 'д.', "33';"],
#     ['г.', 'Москва,', 'ул.', 'Тушинская,', 'д.', "24';"],
#     ['г.', 'Ростов-на-Дону,', 'пер.', 'Нефтяной,', '4', "“A”';"],
#     ['г.', 'Чита,', 'ул.', 'Трактовая,', 'вл.3,', "стр.29';"],
#     ['г.', 'Самара,', 'ул.', 'Товарная,', "д.25';"],
#     ['г.', 'Екатеринбург,', 'ул.', 'Маневровая', '34', "“A”';"],
#     ['г.', 'Хабаровск,', 'пер.', 'Каширский,', "д.1';"],
#     ['г.', 'Энгельс,', 'ул.', 'Тракторная,', "д.1';"],
#     ['г.', 'Гатчина,', 'ул.', 'Жемчужина,', 'д.', "5';"],
#     ['г.', 'Костерево,', 'ул.', "Заречная';"],
#     ['г.', 'Мурманск,', 'ул.', 'Нижне-Ростинское', "шоссе28';"],
#     ['г.', 'Вязьма,', 'ул.', 'Песочная,', "2';"],
#     ['г.', 'Владивосток,', 'ул.', 'Фадеева,', 'д.', "42';"],
#     ['г.',
#      'Москва,',
#      'Очаковское',
#      'шоссе,',
#      'д.',
#      '28',
#      'с.1',
#      '119530,',
#      'г.',
#      'Москва,'],
#     ['г.',
#      'Москве,',
#      'г.',
#      'Лобне',
#      'Московской',
#      'области,',
#      'п.',
#      'Калининец',
#      'Московской',
#      'области,'],
#     ['г.',
#      'Москва,',
#      'Московская',
#      'область,',
#      'г.',
#      'Самара,',
#      'г.',
#      'Ростов-на-Дону,',
#      'г.',
#      'Екатеринбург,'],
#     ['г.',
#      'Москва,',
#      '34',
#      'ПК',
#      'г.',
#      'Москва,',
#      'ОБЛ-Спецтранс',
#      'МО,',
#      'г.',
#      'ЛОБНЯ,']],
#    [['г.', 'Москва,', 'Очаковское', 'шоссе,', 'д.', '28', "с.1';"],
#     ['г.', 'Москва,', 'ул.', 'Искры,', 'д.', "33';"],
#     ['г.', 'Москва,', 'ул.', 'Тушинская,', 'д.', "24';"],
#     ['г.', 'Ростов-на-Дону,', 'пер.', 'Нефтяной,', '4', "“A”';"],
#     ['г.', 'Чита,', 'ул.', 'Трактовая,', 'вл.3,', "стр.29';"],
#     ['г.', 'Самара,', 'ул.', 'Товарная,', "д.25';"],
#     ['г.', 'Екатеринбург,', 'ул.', 'Маневровая', '34', "“A”';"],
#     ['г.', 'Хабаровск,', 'пер.', 'Каширский,', "д.1';"],
#     ['г.', 'Энгельс,', 'ул.', 'Тракторная,', "д.1';"],
#     ['г.', 'Гатчина,', 'ул.', 'Жемчужина,', 'д.', "5';"],
#     ['г.', 'Костерево,', 'ул.', "Заречная';"],
#     ['г.', 'Мурманск,', 'ул.', 'Нижне-Ростинское', "шоссе28';"],
#     ['г.', 'Вязьма,', 'ул.', 'Песочная,', "2';"],
#     ['г.', 'Владивосток,', 'ул.', 'Фадеева,', 'д.', "42';"],
#     ['г.',
#      'Москва,',
#      'Очаковское',
#      'шоссе,',
#      'д.',
#      '28',
#      'с.1',
#      '119530,',
#      'г.',
#      'Москва,'],
#     ['г.',
#      'Москве,',
#      'г.',
#      'Лобне',
#      'Московской',
#      'области,',
#      'п.',
#      'Калининец',
#      'Московской',
#      'области,'],
#     ['г.',
#      'Москва,',
#      'Московская',
#      'область,',
#      'г.',
#      'Самара,',
#      'г.',
#      'Ростов-на-Дону,',
#      'г.',
#      'Екатеринбург,'],
#     ['г.',
#      'Москва,',
#      '34',
#      'ПК',
#      'г.',
#      'Москва,',
#      'ОБЛ-Спецтранс',
#      'МО,',
#      'г.',
#      'ЛОБНЯ,']],
#    [['г.', 'Москва,', 'Очаковское', 'шоссе,', 'д.', '28', "с.1';"],
#     ['г.', 'Москва,', 'ул.', 'Искры,', 'д.', "33';"],
#     ['г.', 'Москва,', 'ул.', 'Тушинская,', 'д.', "24';"],
#     ['г.', 'Ростов-на-Дону,', 'пер.', 'Нефтяной,', '4', "“A”';"],
#     ['г.', 'Чита,', 'ул.', 'Трактовая,', 'вл.3,', "стр.29';"],
#     ['г.', 'Самара,', 'ул.', 'Товарная,', "д.25';"],
#     ['г.', 'Екатеринбург,', 'ул.', 'Маневровая', '34', "“A”';"],
#     ['г.', 'Хабаровск,', 'пер.', 'Каширский,', "д.1';"],
#     ['г.', 'Энгельс,', 'ул.', 'Тракторная,', "д.1';"],
#     ['г.', 'Гатчина,', 'ул.', 'Жемчужина,', 'д.', "5';"],
#     ['г.', 'Костерево,', 'ул.', "Заречная';"],
#     ['г.', 'Мурманск,', 'ул.', 'Нижне-Ростинское', "шоссе28';"],
#     ['г.', 'Вязьма,', 'ул.', 'Песочная,', "2';"],
#     ['г.', 'Владивосток,', 'ул.', 'Фадеева,', 'д.', "42';"],
#     ['г.',
#      'Москва,',
#      'Очаковское',
#      'шоссе,',
#      'д.',
#      '28',
#      'с.1',
#      '119530,',
#      'г.',
#      'Москва,'],
#     ['г.',
#      'Москве,',
#      'г.',
#      'Лобне',
#      'Московской',
#      'области,',
#      'п.',
#      'Калининец',
#      'Московской',
#      'области,'],
#     ['г.',
#      'Москва,',
#      'Московская',
#      'область,',
#      'г.',
#      'Самара,',
#      'г.',
#      'Ростов-на-Дону,',
#      'г.',
#      'Екатеринбург,'],
#     ['г.',
#      'Москва,',
#      '34',
#      'ПК',
#      'г.',
#      'Москва,',
#      'ОБЛ-Спецтранс',
#      'МО,',
#      'г.',
#      'ЛОБНЯ,']],
#    [['г.', 'Москва,', 'Очаковское', 'шоссе,', 'д.', '28', "с.1';"],
#     ['г.', 'Москва,', 'ул.', 'Искры,', 'д.', "33';"],
#     ['г.', 'Москва,', 'ул.', 'Тушинская,', 'д.', "24';"],
#     ['г.', 'Ростов-на-Дону,', 'пер.', 'Нефтяной,', '4', "“A”';"],
#     ['г.', 'Чита,', 'ул.', 'Трактовая,', 'вл.3,', "стр.29';"],
#     ['г.', 'Самара,', 'ул.', 'Товарная,', "д.25';"],
#     ['г.', 'Екатеринбург,', 'ул.', 'Маневровая', '34', "“A”';"],
#     ['г.', 'Хабаровск,', 'пер.', 'Каширский,', "д.1';"],
#     ['г.', 'Энгельс,', 'ул.', 'Тракторная,', "д.1';"],
#     ['г.', 'Гатчина,', 'ул.', 'Жемчужина,', 'д.', "5';"],
#     ['г.', 'Костерево,', 'ул.', "Заречная';"],
#     ['г.', 'Мурманск,', 'ул.', 'Нижне-Ростинское', "шоссе28';"],
#     ['г.', 'Вязьма,', 'ул.', 'Песочная,', "2';"],
#     ['г.', 'Владивосток,', 'ул.', 'Фадеева,', 'д.', "42';"],
#     ['г.',
#      'Москва,',
#      'Очаковское',
#      'шоссе,',
#      'д.',
#      '28',
#      'с.1',
#      '119530,',
#      'г.',
#      'Москва,'],
#     ['г.',
#      'Москве,',
#      'г.',
#      'Лобне',
#      'Московской',
#      'области,',
#      'п.',
#      'Калининец',
#      'Московской',
#      'области,'],
#     ['г.',
#      'Москва,',
#      'Московская',
#      'область,',
#      'г.',
#      'Самара,',
#      'г.',
#      'Ростов-на-Дону,',
#      'г.',
#      'Екатеринбург,'],
#     ['г.',
#      'Москва,',
#      '34',
#      'ПК',
#      'г.',
#      'Москва,',
#      'ОБЛ-Спецтранс',
#      'МО,',
#      'г.',
#      'ЛОБНЯ,']],
#    [['г.', 'Москва,', 'Очаковское', 'шоссе,', 'д.', '28', "с.1';"],
#     ['г.', 'Москва,', 'ул.', 'Искры,', 'д.', "33';"],
#     ['г.', 'Москва,', 'ул.', 'Тушинская,', 'д.', "24';"],
#     ['г.', 'Ростов-на-Дону,', 'пер.', 'Нефтяной,', '4', "“A”';"],
#     ['г.', 'Чита,', 'ул.', 'Трактовая,', 'вл.3,', "стр.29';"],
#     ['г.', 'Самара,', 'ул.', 'Товарная,', "д.25';"],
#     ['г.', 'Екатеринбург,', 'ул.', 'Маневровая', '34', "“A”';"],
#     ['г.', 'Хабаровск,', 'пер.', 'Каширский,', "д.1';"],
#     ['г.', 'Энгельс,', 'ул.', 'Тракторная,', "д.1';"],
#     ['г.', 'Гатчина,', 'ул.', 'Жемчужина,', 'д.', "5';"],
#     ['г.', 'Костерево,', 'ул.', "Заречная';"],
#     ['г.', 'Мурманск,', 'ул.', 'Нижне-Ростинское', "шоссе28';"],
#     ['г.', 'Вязьма,', 'ул.', 'Песочная,', "2';"],
#     ['г.', 'Владивосток,', 'ул.', 'Фадеева,', 'д.', "42';"],
#     ['г.',
#      'Москва,',
#      'Очаковское',
#      'шоссе,',
#      'д.',
#      '28',
#      'с.1',
#      '119530,',
#      'г.',
#      'Москва,'],
#     ['г.',
#      'Москве,',
#      'г.',
#      'Лобне',
#      'Московской',
#      'области,',
#      'п.',
#      'Калининец',
#      'Московской',
#      'области,'],
#     ['г.',
#      'Москва,',
#      'Московская',
#      'область,',
#      'г.',
#      'Самара,',
#      'г.',
#      'Ростов-на-Дону,',
#      'г.',
#      'Екатеринбург,'],
#     ['г.',
#      'Москва,',
#      '34',
#      'ПК',
#      'г.',
#      'Москва,',
#      'ОБЛ-Спецтранс',
#      'МО,',
#      'г.',
#      'ЛОБНЯ,']],
#    [['г.', 'Москва,', 'Очаковское', 'шоссе,', 'д.', '28', "с.1';"],
#     ['г.', 'Москва,', 'ул.', 'Искры,', 'д.', "33';"],
#     ['г.', 'Москва,', 'ул.', 'Тушинская,', 'д.', "24';"],
#     ['г.', 'Ростов-на-Дону,', 'пер.', 'Нефтяной,', '4', "“A”';"],
#     ['г.', 'Чита,', 'ул.', 'Трактовая,', 'вл.3,', "стр.29';"],
#     ['г.', 'Самара,', 'ул.', 'Товарная,', "д.25';"],
#     ['г.', 'Екатеринбург,', 'ул.', 'Маневровая', '34', "“A”';"],
#     ['г.', 'Хабаровск,', 'пер.', 'Каширский,', "д.1';"],
#     ['г.', 'Энгельс,', 'ул.', 'Тракторная,', "д.1';"],
#     ['г.', 'Гатчина,', 'ул.', 'Жемчужина,', 'д.', "5';"],
#     ['г.', 'Костерево,', 'ул.', "Заречная';"],
#     ['г.', 'Мурманск,', 'ул.', 'Нижне-Ростинское', "шоссе28';"],
#     ['г.', 'Вязьма,', 'ул.', 'Песочная,', "2';"],
#     ['г.', 'Владивосток,', 'ул.', 'Фадеева,', 'д.', "42';"],
#     ['г.',
#      'Москва,',
#      'Очаковское',
#      'шоссе,',
#      'д.',
#      '28',
#      'с.1',
#      '119530,',
#      'г.',
#      'Москва,'],
#     ['г.',
#      'Москве,',
#      'г.',
#      'Лобне',
#      'Московской',
#      'области,',
#      'п.',
#      'Калининец',
#      'Московской',
#      'области,'],
#     ['г.',
#      'Москва,',
#      'Московская',
#      'область,',
#      'г.',
#      'Самара,',
#      'г.',
#      'Ростов-на-Дону,',
#      'г.',
#      'Екатеринбург,'],
#     ['г.',
#      'Москва,',
#      '34',
#      'ПК',
#      'г.',
#      'Москва,',
#      'ОБЛ-Спецтранс',
#      'МО,',
#      'г.',
#      'ЛОБНЯ,']]]],
#  ['https://1lion.ru',
#   array(['79788046535', '89788580000'], dtype='<U11'),
#   None,
#   None,
#   None,
#   [['г.', 'Алушта', 'ул.', 'Вл.', 'Хромых,', '29,', '2', 'эт.', 'офис', '№2'],
#    ['г.',
#     'Алушта',
#     'Тип:',
#     'Участок',
#     'Площадь:',
#     '7',
#     'сот.',
#     'Назначение:',
#     'ИЖС',
#     '2'],
#    ['г.',
#     'Алушта',
#     'Тип:',
#     'Участок',
#     'Площадь:',
#     '8',
#     'сот.',
#     'Назначение:',
#     'ИЖС',
#     '3'],
#    ['г.',
#     'Алушта',
#     'Тип:',
#     'Квартира',
#     'Комнат:',
#     '2',
#     'Площадь:',
#     '60',
#     'м²',
#     'Этаж:'],
#    ['г.',
#     'Алушта',
#     'Тип:',
#     'Квартира',
#     'Комнат:',
#     'студия',
#     'Площадь:',
#     '30',
#     'м²',
#     'Этаж:'],
#    ['г.',
#     'Алушта',
#     'Тип:',
#     'Квартира',
#     'Комнат:',
#     'студия',
#     'Площадь:',
#     '21.7',
#     'м²',
#     'Этаж:'],
#    ['г.',
#     'Алушта',
#     'Тип:',
#     'Квартира',
#     'Комнат:',
#     '1',
#     'Площадь:',
#     '17.9',
#     'м²',
#     'Этаж:'],
#    ['г.',
#     'Алушта',
#     'Тип:',
#     'Квартира',
#     'Комнат:',
#     '3',
#     'Площадь:',
#     '52.5',
#     'м²',
#     'Этаж:'],
#    ['г',
#     'Для',
#     'владельцев',
#     'Жилые',
#     'комплексы',
#     'Наша',
#     'команда',
#     'Контакты',
#     'Блог',
#     'Избранное'],
#    [['г.', 'Алушта', 'ул.', 'Вл.', 'Хромых,', '29,', '2', 'эт.', 'офис', '№2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '7',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '8',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '3'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '2',
#      'Площадь:',
#      '60',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '30',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '21.7',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '1',
#      'Площадь:',
#      '17.9',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '3',
#      'Площадь:',
#      '52.5',
#      'м²',
#      'Этаж:'],
#     ['г',
#      'Для',
#      'владельцев',
#      'Жилые',
#      'комплексы',
#      'Наша',
#      'команда',
#      'Контакты',
#      'Блог',
#      'Избранное']],
#    [['г.', 'Алушта', 'ул.', 'Вл.', 'Хромых,', '29,', '2', 'эт.', 'офис', '№2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '7',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '8',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '3'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '2',
#      'Площадь:',
#      '60',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '30',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '21.7',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '1',
#      'Площадь:',
#      '17.9',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '3',
#      'Площадь:',
#      '52.5',
#      'м²',
#      'Этаж:'],
#     ['г',
#      'Для',
#      'владельцев',
#      'Жилые',
#      'комплексы',
#      'Наша',
#      'команда',
#      'Контакты',
#      'Блог',
#      'Избранное']],
#    [['г.', 'Алушта', 'ул.', 'Вл.', 'Хромых,', '29,', '2', 'эт.', 'офис', '№2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '7',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '8',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '3'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '2',
#      'Площадь:',
#      '60',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '30',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '21.7',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '1',
#      'Площадь:',
#      '17.9',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '3',
#      'Площадь:',
#      '52.5',
#      'м²',
#      'Этаж:'],
#     ['г',
#      'Для',
#      'владельцев',
#      'Жилые',
#      'комплексы',
#      'Наша',
#      'команда',
#      'Контакты',
#      'Блог',
#      'Избранное']],
#    [['г.', 'Алушта', 'ул.', 'Вл.', 'Хромых,', '29,', '2', 'эт.', 'офис', '№2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '7',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '8',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '3'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '2',
#      'Площадь:',
#      '60',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '30',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '21.7',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '1',
#      'Площадь:',
#      '17.9',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '3',
#      'Площадь:',
#      '52.5',
#      'м²',
#      'Этаж:'],
#     ['г',
#      'Для',
#      'владельцев',
#      'Жилые',
#      'комплексы',
#      'Наша',
#      'команда',
#      'Контакты',
#      'Блог',
#      'Избранное']],
#    [['г.', 'Алушта', 'ул.', 'Вл.', 'Хромых,', '29,', '2', 'эт.', 'офис', '№2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '7',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '8',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '3'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '2',
#      'Площадь:',
#      '60',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '30',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '21.7',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '1',
#      'Площадь:',
#      '17.9',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '3',
#      'Площадь:',
#      '52.5',
#      'м²',
#      'Этаж:'],
#     ['г',
#      'Для',
#      'владельцев',
#      'Жилые',
#      'комплексы',
#      'Наша',
#      'команда',
#      'Контакты',
#      'Блог',
#      'Избранное']],
#    [['г.', 'Алушта', 'ул.', 'Вл.', 'Хромых,', '29,', '2', 'эт.', 'офис', '№2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '7',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '8',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '3'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '2',
#      'Площадь:',
#      '60',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '30',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '21.7',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '1',
#      'Площадь:',
#      '17.9',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '3',
#      'Площадь:',
#      '52.5',
#      'м²',
#      'Этаж:'],
#     ['г',
#      'Для',
#      'владельцев',
#      'Жилые',
#      'комплексы',
#      'Наша',
#      'команда',
#      'Контакты',
#      'Блог',
#      'Избранное']],
#    [['г.', 'Алушта', 'ул.', 'Вл.', 'Хромых,', '29,', '2', 'эт.', 'офис', '№2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '7',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '8',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '3'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '2',
#      'Площадь:',
#      '60',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '30',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '21.7',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '1',
#      'Площадь:',
#      '17.9',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '3',
#      'Площадь:',
#      '52.5',
#      'м²',
#      'Этаж:'],
#     ['г',
#      'Для',
#      'владельцев',
#      'Жилые',
#      'комплексы',
#      'Наша',
#      'команда',
#      'Контакты',
#      'Блог',
#      'Избранное']],
#    [['г.', 'Алушта', 'ул.', 'Вл.', 'Хромых,', '29,', '2', 'эт.', 'офис', '№2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '7',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '2'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Участок',
#      'Площадь:',
#      '8',
#      'сот.',
#      'Назначение:',
#      'ИЖС',
#      '3'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '2',
#      'Площадь:',
#      '60',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '30',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      'студия',
#      'Площадь:',
#      '21.7',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '1',
#      'Площадь:',
#      '17.9',
#      'м²',
#      'Этаж:'],
#     ['г.',
#      'Алушта',
#      'Тип:',
#      'Квартира',
#      'Комнат:',
#      '3',
#      'Площадь:',
#      '52.5',
#      'м²',
#      'Этаж:'],
#     ['г',
#      'Для',
#      'владельцев',
#      'Жилые',
#      'комплексы',
#      'Наша',
#      'команда',
#      'Контакты',
#      'Блог',
#      'Избранное']]]],
#  ['https://1strela.ru',
#   array(['88126003333', '88127405018'], dtype='<U11'),
#   'sales@1strela.ru',
#   None,
#   None,
#   [[], [], [], [], [], [], [], []]],
#  ['https://203000.ru',
#   array(['8412203000'], dtype='<U10'),
#   None,
#   ['_3322728009_', '_3302092990_'],
#   None,
#   [['г.',
#     'Пенза,',
#     'ул.',
#     '65-летия',
#     'Победы,',
#     '29',
#     'г.',
#     'Пенза,',
#     'ул.',
#     'Ульяновская'],
#    [['г.',
#      'Пенза,',
#      'ул.',
#      '65-летия',
#      'Победы,',
#      '29',
#      'г.',
#      'Пенза,',
#      'ул.',
#      'Ульяновская']],
#    [['г.',
#      'Пенза,',
#      'ул.',
#      '65-летия',
#      'Победы,',
#      '29',
#      'г.',
#      'Пенза,',
#      'ул.',
#      'Ульяновская']],
#    [['г.',
#      'Пенза,',
#      'ул.',
#      '65-летия',
#      'Победы,',
#      '29',
#      'г.',
#      'Пенза,',
#      'ул.',
#      'Ульяновская']],
#    [['г.',
#      'Пенза,',
#      'ул.',
#      '65-летия',
#      'Победы,',
#      '29',
#      'г.',
#      'Пенза,',
#      'ул.',
#      'Ульяновская']],
#    [['г.',
#      'Пенза,',
#      'ул.',
#      '65-летия',
#      'Победы,',
#      '29',
#      'г.',
#      'Пенза,',
#      'ул.',
#      'Ульяновская']],
#    [['г.',
#      'Пенза,',
#      'ул.',
#      '65-летия',
#      'Победы,',
#      '29',
#      'г.',
#      'Пенза,',
#      'ул.',
#      'Ульяновская']],
#    [['г.',
#      'Пенза,',
#      'ул.',
#      '65-летия',
#      'Победы,',
#      '29',
#      'г.',
#      'Пенза,',
#      'ул.',
#      'Ульяновская']],
#    [['г.',
#      'Пенза,',
#      'ул.',
#      '65-летия',
#      'Победы,',
#      '29',
#      'г.',
#      'Пенза,',
#      'ул.',
#      'Ульяновская']]]],
#  ['https://214g.ru',
#   array(['78129202297'], dtype='<U11'),
#   'info@214g.ru',
#   None,
#   None,
#   [[], [], [], [], [], [], [], []]],
#  ['https://23kvartiri.ru',
#   array(['88002001023'], dtype='<U11'),
#   None,
#   ['_1440314172_'],
#   ['.8853321075439'],
#   [[], [], [], [], [], [], [], []]],
#  ['https://2volga.ru',
#   array(['79154635186', '89154635186'], dtype='<U11'),
#   'sale@2volga.ru',
#   None,
#   None,
#   [[], [], [], [], [], [], [], []]],
#  ['https://2wk.ru',
#   array(['74999389659', '76261373532'], dtype='<U11'),
#   None,
#   ['_3966226736_'],
#   None,
#   [['г.',
#     'Детские',
#     'сады',
#     'и',
#     'школа.',
#     'Квартиры',
#     'от',
#     '5.4',
#     'до',
#     '13.4'],
#    ['г.',
#     'Детские',
#     'сады',
#     'и',
#     'школа.',
#     'Квартиры',
#     'от',
#     '8.1',
#     'до',
#     '11.6'],
#    ['г.',
#     'Детские',
#     'сады',
#     'и',
#     'школы.',
#     'Квартиры',
#     'от',
#     '5.9',
#     'до',
#     '16.9'],
#    ['г.',
#     'Детский',
#     'сад',
#     'и',
#     'школа.',
#     'Квартиры',
#     'от',
#     '4.6',
#     'до',
#     '12.3'],
#    ['г.',
#     'Детские',
#     'сады',
#     'и',
#     'школы.',
#     'Квартиры',
#     'от',
#     '3.8',
#     'до',
#     '10.3'],
#    ['г.',
#     'Детский',
#     'сад',
#     'и',
#     'школа.',
#     'Квартиры',
#     'от',
#     '4.4',
#     'до',
#     '16'],
#    ['г.', 'Детский', 'сад', 'и', 'школа.', 'Квартиры', 'от', '4', 'до', '10'],
#    ['г.',
#     'Детские',
#     'сады',
#     'и',
#     'школа.',
#     'Квартиры',
#     'от',
#     '2.4',
#     'до',
#     '12.8'],
#    [['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '5.4',
#      'до',
#      '13.4'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '8.1',
#      'до',
#      '11.6'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '5.9',
#      'до',
#      '16.9'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.6',
#      'до',
#      '12.3'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '3.8',
#      'до',
#      '10.3'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.4',
#      'до',
#      '16'],
#     ['г.', 'Детский', 'сад', 'и', 'школа.', 'Квартиры', 'от', '4', 'до', '10'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '2.4',
#      'до',
#      '12.8']],
#    [['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '5.4',
#      'до',
#      '13.4'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '8.1',
#      'до',
#      '11.6'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '5.9',
#      'до',
#      '16.9'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.6',
#      'до',
#      '12.3'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '3.8',
#      'до',
#      '10.3'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.4',
#      'до',
#      '16'],
#     ['г.', 'Детский', 'сад', 'и', 'школа.', 'Квартиры', 'от', '4', 'до', '10'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '2.4',
#      'до',
#      '12.8']],
#    [['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '5.4',
#      'до',
#      '13.4'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '8.1',
#      'до',
#      '11.6'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '5.9',
#      'до',
#      '16.9'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.6',
#      'до',
#      '12.3'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '3.8',
#      'до',
#      '10.3'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.4',
#      'до',
#      '16'],
#     ['г.', 'Детский', 'сад', 'и', 'школа.', 'Квартиры', 'от', '4', 'до', '10'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '2.4',
#      'до',
#      '12.8']],
#    [['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '5.4',
#      'до',
#      '13.4'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '8.1',
#      'до',
#      '11.6'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '5.9',
#      'до',
#      '16.9'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.6',
#      'до',
#      '12.3'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '3.8',
#      'до',
#      '10.3'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.4',
#      'до',
#      '16'],
#     ['г.', 'Детский', 'сад', 'и', 'школа.', 'Квартиры', 'от', '4', 'до', '10'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '2.4',
#      'до',
#      '12.8']],
#    [['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '5.4',
#      'до',
#      '13.4'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '8.1',
#      'до',
#      '11.6'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '5.9',
#      'до',
#      '16.9'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.6',
#      'до',
#      '12.3'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '3.8',
#      'до',
#      '10.3'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.4',
#      'до',
#      '16'],
#     ['г.', 'Детский', 'сад', 'и', 'школа.', 'Квартиры', 'от', '4', 'до', '10'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '2.4',
#      'до',
#      '12.8']],
#    [['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '5.4',
#      'до',
#      '13.4'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '8.1',
#      'до',
#      '11.6'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '5.9',
#      'до',
#      '16.9'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.6',
#      'до',
#      '12.3'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '3.8',
#      'до',
#      '10.3'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.4',
#      'до',
#      '16'],
#     ['г.', 'Детский', 'сад', 'и', 'школа.', 'Квартиры', 'от', '4', 'до', '10'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '2.4',
#      'до',
#      '12.8']],
#    [['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '5.4',
#      'до',
#      '13.4'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '8.1',
#      'до',
#      '11.6'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '5.9',
#      'до',
#      '16.9'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.6',
#      'до',
#      '12.3'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '3.8',
#      'до',
#      '10.3'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.4',
#      'до',
#      '16'],
#     ['г.', 'Детский', 'сад', 'и', 'школа.', 'Квартиры', 'от', '4', 'до', '10'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '2.4',
#      'до',
#      '12.8']],
#    [['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '5.4',
#      'до',
#      '13.4'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '8.1',
#      'до',
#      '11.6'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '5.9',
#      'до',
#      '16.9'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.6',
#      'до',
#      '12.3'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школы.',
#      'Квартиры',
#      'от',
#      '3.8',
#      'до',
#      '10.3'],
#     ['г.',
#      'Детский',
#      'сад',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '4.4',
#      'до',
#      '16'],
#     ['г.', 'Детский', 'сад', 'и', 'школа.', 'Квартиры', 'от', '4', 'до', '10'],
#     ['г.',
#      'Детские',
#      'сады',
#      'и',
#      'школа.',
#      'Квартиры',
#      'от',
#      '2.4',
#      'до',
#      '12.8']]]],
#  ['https://33land.ru',
#   array(['84951506501'], dtype='<U11'),
#   'info@33land.ru',
#   ['_3966226736_'],
#   None,
#   [['г.', 'Солнечногорск', '“Здравствуйте.'],
#    ['г.', 'Москва', '“Давно', 'мечтали', 'купить', 'участок,', 'но', 'каждый'],
#    ['г.',
#     'Москва',
#     '“Здравствуйте,',
#     'наша',
#     'семья',
#     'долго',
#     'искала',
#     'земельный'],
#    ['г.',
#     'Северодвинск',
#     '“Хочу',
#     'выразить',
#     'свою',
#     'благодарность',
#     'за',
#     'помощь'],
#    ['г.',
#     'Костерево',
#     '“Я',
#     'купил',
#     'себе',
#     'участок',
#     'на',
#     'территории',
#     'деревни'],
#    ['г.',
#     'Балашиха',
#     '“В',
#     'марте',
#     '2023',
#     'года',
#     'мы',
#     'решились',
#     'на',
#     'покупку'],
#    ['г.', 'Москва', '“Выбирали', 'участок', 'в', 'течение', 'года.'],
#    ['г.', 'Москва', '“Выражаем', 'огромную', 'благодарность,', 'всей'],
#    ['г.', 'Москва', '“Совершенно', 'внезапно', 'решили', 'купить', 'участок'],
#    ['г.', 'Москва', '“Благодарим', 'Прокудина', 'Виктора', 'Алексеевича'],
#    ['г.',
#     'Москва',
#     '“Мы',
#     'решились',
#     'на',
#     'покупку',
#     'земельного',
#     'участка,'],
#    ['г.', 'Москва', '“Старшие', 'сыновья', 'задумались', 'о', 'приобретении'],
#    ['г.',
#     'Москва',
#     '“Летом',
#     '2020',
#     'года',
#     'мы',
#     'с',
#     'братьями',
#     'искали',
#     'земельный'],
#    ['г.',
#     'Москва',
#     '“Летом',
#     '2020',
#     'года,',
#     'было',
#     'решение',
#     'купить',
#     'земельный'],
#    ['г.', 'Москва', '“Приобретение', 'земли', 'во', 'Владимирской', 'области'],
#    ['г.',
#     'Москва',
#     '“Благодарю',
#     'Виктора',
#     'Алексеевича',
#     'за',
#     'интересную'],
#    ['г.',
#     'Реутов',
#     '“Давно',
#     'с',
#     'супругой',
#     'хотели',
#     'приобрести',
#     'участок'],
#    ['г.', 'Москва', '“Всём', 'привет.', 'Долго', 'выбирали', 'участок', 'во'],
#    ['г.',
#     'Москва',
#     '“2',
#     'февраля',
#     '2019',
#     'года',
#     'к',
#     'своим',
#     'двум',
#     'смежным'],
#    ['г.', 'Москва', '“Большую', 'благодарность', 'выражаю', 'компании'],
#    ['г.',
#     'Балашиха',
#     '“Спешу',
#     'поделится',
#     'с',
#     'Вами',
#     'радостным',
#     'для',
#     'меня'],
#    ['г.', 'Москва', '“Наша', 'семья', 'приобрела', 'земельный', 'участок'],
#    ['г.', 'Балашиха', '“Приобрели', 'с', 'супругой', 'большой', 'земельный'],
#    ['г.', 'Пенза', '“Хочется', 'оставить', 'положительный', 'отзыв', 'о'],
#    ['г.',
#     'Москва',
#     '“В',
#     '2019',
#     'году',
#     'мы',
#     'решились',
#     'на',
#     'покупку',
#     'третьего'],
#    ['г.', 'Люберцы', '“Мы', 'решила', 'купить', 'землю', 'для', 'загородного'],
#    ['г.',
#     'Петушки',
#     '“Благодарю',
#     'всех',
#     'сотрудников',
#     'компании',
#     '"Владимирская'],
#    ['г.',
#     'Москва',
#     '“Сбылась',
#     'мечта',
#     'нашей',
#     'семьи!...”',
#     'Весь',
#     'отзыв',
#     'Екатерина',
#     'г.'],
#    ['г.',
#     'Москва',
#     '“Для',
#     'меня',
#     'г.',
#     'Петушки',
#     'и',
#     'озеро',
#     'Грибовское,'],
#    ['г.', 'Москва', '“Ребёнок', 'мечтал', 'о', 'даче....'],
#    ['г.',
#     'Реутов',
#     '“Наверное,',
#     'как',
#     'и',
#     'очень',
#     'многие',
#     'другие,',
#     'мы'],
#    ['г.',
#     'Москва',
#     '“Выражаем',
#     'благодарность',
#     'агентству',
#     '"Владимирская'],
#    ['г.',
#     'Балашиха',
#     '“Покупкой',
#     'второго',
#     'участка',
#     'в',
#     'д.',
#     'Аббакумово'],
#    ['г.', 'Москва', '“Здравствуйте!'],
#    ['г.', 'Москва', '“Добрый', 'день.'],
#    ['г.',
#     'Петушки,',
#     'ул.',
#     'Советская',
#     'площадь,',
#     'дом',
#     '16,',
#     'офис',
#     '2.',
#     'Мы'],
#    ['г.', 'Петушки",'],
#    [['г.', 'Солнечногорск', '“Здравствуйте.'],
#     ['г.',
#      'Москва',
#      '“Давно',
#      'мечтали',
#      'купить',
#      'участок,',
#      'но',
#      'каждый'],
#     ['г.',
#      'Москва',
#      '“Здравствуйте,',
#      'наша',
#      'семья',
#      'долго',
#      'искала',
#      'земельный'],
#     ['г.',
#      'Северодвинск',
#      '“Хочу',
#      'выразить',
#      'свою',
#      'благодарность',
#      'за',
#      'помощь'],
#     ['г.',
#      'Костерево',
#      '“Я',
#      'купил',
#      'себе',
#      'участок',
#      'на',
#      'территории',
#      'деревни'],
#     ['г.',
#      'Балашиха',
#      '“В',
#      'марте',
#      '2023',
#      'года',
#      'мы',
#      'решились',
#      'на',
#      'покупку'],
#     ['г.', 'Москва', '“Выбирали', 'участок', 'в', 'течение', 'года.'],
#     ['г.', 'Москва', '“Выражаем', 'огромную', 'благодарность,', 'всей'],
#     ['г.', 'Москва', '“Совершенно', 'внезапно', 'решили', 'купить', 'участок'],
#     ['г.', 'Москва', '“Благодарим', 'Прокудина', 'Виктора', 'Алексеевича'],
#     ['г.',
#      'Москва',
#      '“Мы',
#      'решились',
#      'на',
#      'покупку',
#      'земельного',
#      'участка,'],
#     ['г.', 'Москва', '“Старшие', 'сыновья', 'задумались', 'о', 'приобретении'],
#     ['г.',
#      'Москва',
#      '“Летом',
#      '2020',
#      'года',
#      'мы',
#      'с',
#      'братьями',
#      'искали',
#      'земельный'],
#     ['г.',
#      'Москва',
#      '“Летом',
#      '2020',
#      'года,',
#      'было',
#      'решение',
#      'купить',
#      'земельный'],
#     ['г.',
#      'Москва',
#      '“Приобретение',
#      'земли',
#      'во',
#      'Владимирской',
#      'области'],
#     ['г.',
#      'Москва',
#      '“Благодарю',
#      'Виктора',
#      'Алексеевича',
#      'за',
#      'интересную'],
#     ['г.',
#      'Реутов',
#      '“Давно',
#      'с',
#      'супругой',
#      'хотели',
#      'приобрести',
#      'участок'],
#     ['г.', 'Москва', '“Всём', 'привет.', 'Долго', 'выбирали', 'участок', 'во'],
#     ['г.',
#      'Москва',
#      '“2',
#      'февраля',
#      '2019',
#      'года',
#      'к',
#      'своим',
#      'двум',
#      'смежным'],
#     ['г.', 'Москва', '“Большую', 'благодарность', 'выражаю', 'компании'],
#     ['г.',
#      'Балашиха',
#      '“Спешу',
#      'поделится',
#      'с',
#      'Вами',
#      'радостным',
#      'для',
#      'меня'],
#     ['г.', 'Москва', '“Наша', 'семья', 'приобрела', 'земельный', 'участок'],
#     ['г.', 'Балашиха', '“Приобрели', 'с', 'супругой', 'большой', 'земельный'],
#     ['г.', 'Пенза', '“Хочется', 'оставить', 'положительный', 'отзыв', 'о'],
#     ['г.',
#      'Москва',
#      '“В',
#      '2019',
#      'году',
#      'мы',
#      'решились',
#      'на',
#      'покупку',
#      'третьего'],
#     ['г.',
#      'Люберцы',
#      '“Мы',
#      'решила',
#      'купить',
#      'землю',
#      'для',
#      'загородного'],
#     ['г.',
#      'Петушки',
#      '“Благодарю',
#      'всех',
#      'сотрудников',
#      'компании',
#      '"Владимирская'],
#     ['г.',
#      'Москва',
#      '“Сбылась',
#      'мечта',
#      'нашей',
#      'семьи!...”',
#      'Весь',
#      'отзыв',
#      'Екатерина',
#      'г.'],
#     ['г.',
#      'Москва',
#      '“Для',
#      'меня',
#      'г.',
#      'Петушки',
#      'и',
#      'озеро',
#      'Грибовское,'],
#     ['г.', 'Москва', '“Ребёнок', 'мечтал', 'о', 'даче....'],
#     ['г.',
#      'Реутов',
#      '“Наверное,',
#      'как',
#      'и',
#      'очень',
#      'многие',
#      'другие,',
#      'мы'],
#     ['г.',
#      'Москва',
#      '“Выражаем',
#      'благодарность',
#      'агентству',
#      '"Владимирская'],
#     ['г.',
#      'Балашиха',
#      '“Покупкой',
#      'второго',
#      'участка',
#      'в',
#      'д.',
#      'Аббакумово'],
#     ['г.', 'Москва', '“Здравствуйте!'],
#     ['г.', 'Москва', '“Добрый', 'день.'],
#     ['г.',
#      'Петушки,',
#      'ул.',
#      'Советская',
#      'площадь,',
#      'дом',
#      '16,',
#      'офис',
#      '2.',
#      'Мы'],
#     ['г.', 'Петушки",']],
#    [['г.', 'Солнечногорск', '“Здравствуйте.'],
#     ['г.',
#      'Москва',
#      '“Давно',
#      'мечтали',
#      'купить',
#      'участок,',
#      'но',
#      'каждый'],
#     ['г.',
#      'Москва',
#      '“Здравствуйте,',
#      'наша',
#      'семья',
#      'долго',
#      'искала',
#      'земельный'],
#     ['г.',
#      'Северодвинск',
#      '“Хочу',
#      'выразить',
#      'свою',
#      'благодарность',
#      'за',
#      'помощь'],
#     ['г.',
#      'Костерево',
#      '“Я',
#      'купил',
#      'себе',
#      'участок',
#      'на',
#      'территории',
#      'деревни'],
#     ['г.',
#      'Балашиха',
#      '“В',
#      'марте',
#      '2023',
#      'года',
#      'мы',
#      'решились',
#      'на',
#      'покупку'],
#     ['г.', 'Москва', '“Выбирали', 'участок', 'в', 'течение', 'года.'],
#     ['г.', 'Москва', '“Выражаем', 'огромную', 'благодарность,', 'всей'],
#     ['г.', 'Москва', '“Совершенно', 'внезапно', 'решили', 'купить', 'участок'],
#     ['г.', 'Москва', '“Благодарим', 'Прокудина', 'Виктора', 'Алексеевича'],
#     ['г.',
#      'Москва',
#      '“Мы',
#      'решились',
#      'на',
#      'покупку',
#      'земельного',
#      'участка,'],
#     ['г.', 'Москва', '“Старшие', 'сыновья', 'задумались', 'о', 'приобретении'],
#     ['г.',
#      'Москва',
#      '“Летом',
#      '2020',
#      'года',
#      'мы',
#      'с',
#      'братьями',
#      'искали',
#      'земельный'],
#     ['г.',
#      'Москва',
#      '“Летом',
#      '2020',
#      'года,',
#      'было',
#      'решение',
#      'купить',
#      'земельный'],
#     ['г.',
#      'Москва',
#      '“Приобретение',
#      'земли',
#      'во',
#      'Владимирской',
#      'области'],
#     ['г.',
#      'Москва',
#      '“Благодарю',
#      'Виктора',
#      'Алексеевича',
#      'за',
#      'интересную'],
#     ['г.',
#      'Реутов',
#      '“Давно',
#      'с',
#      'супругой',
#      'хотели',
#      'приобрести',
#      'участок'],
#     ['г.', 'Москва', '“Всём', 'привет.', 'Долго', 'выбирали', 'участок', 'во'],
#     ['г.',
#      'Москва',
#      '“2',
#      'февраля',
#      '2019',
#      'года',
#      'к',
#      'своим',
#      'двум',
#      'смежным'],
#     ['г.', 'Москва', '“Большую', 'благодарность', 'выражаю', 'компании'],
#     ['г.',
#      'Балашиха',
#      '“Спешу',
#      'поделится',
#      'с',
#      'Вами',
#      'радостным',
#      'для',
#      'меня'],
#     ['г.', 'Москва', '“Наша', 'семья', 'приобрела', 'земельный', 'участок'],
#     ['г.', 'Балашиха', '“Приобрели', 'с', 'супругой', 'большой', 'земельный'],
#     ['г.', 'Пенза', '“Хочется', 'оставить', 'положительный', 'отзыв', 'о'],
#     ['г.',
#      'Москва',
#      '“В',
#      '2019',
#      'году',
#      'мы',
#      'решились',
#      'на',
#      'покупку',
#      'третьего'],
#     ['г.',
#      'Люберцы',
#      '“Мы',
#      'решила',
#      'купить',
#      'землю',
#      'для',
#      'загородного'],
#     ['г.',
#      'Петушки',
#      '“Благодарю',
#      'всех',
#      'сотрудников',
#      'компании',
#      '"Владимирская'],
#     ['г.',
#      'Москва',
#      '“Сбылась',
#      'мечта',
#      'нашей',
#      'семьи!...”',
#      'Весь',
#      'отзыв',
#      'Екатерина',
#      'г.'],
#     ['г.',
#      'Москва',
#      '“Для',
#      'меня',
#      'г.',
#      'Петушки',
#      'и',
#      'озеро',
#      'Грибовское,'],
#     ['г.', 'Москва', '“Ребёнок', 'мечтал', 'о', 'даче....'],
#     ['г.',
#      'Реутов',
#      '“Наверное,',
#      'как',
#      'и',
#      'очень',
#      'многие',
#      'другие,',
#      'мы'],
#     ['г.',
#      'Москва',
#      '“Выражаем',
#      'благодарность',
#      'агентству',
#      '"Владимирская'],
#     ['г.',
#      'Балашиха',
#      '“Покупкой',
#      'второго',
#      'участка',
#      'в',
#      'д.',
#      'Аббакумово'],
#     ['г.', 'Москва', '“Здравствуйте!'],
#     ['г.', 'Москва', '“Добрый', 'день.'],
#     ['г.',
#      'Петушки,',
#      'ул.',
#      'Советская',
#      'площадь,',
#      'дом',
#      '16,',
#      'офис',
#      '2.',
#      'Мы'],
#     ['г.', 'Петушки",']],
#    [['г.', 'Солнечногорск', '“Здравствуйте.'],
#     ['г.',
#      'Москва',
#      '“Давно',
#      'мечтали',
#      'купить',
#      'участок,',
#      'но',
#      'каждый'],
#     ['г.',
#      'Москва',
#      '“Здравствуйте,',
#      'наша',
#      'семья',
#      'долго',
#      'искала',
#      'земельный'],
#     ['г.',
#      'Северодвинск',
#      '“Хочу',
#      'выразить',
#      'свою',
#      'благодарность',
#      'за',
#      'помощь'],
#     ['г.',
#      'Костерево',
#      '“Я',
#      'купил',
#      'себе',
#      'участок',
#      'на',
#      'территории',
#      'деревни'],
#     ['г.',
# ...
#      'Ростов-на-Дону',
#      'Заказать',
#      'звонок',
#      '<li>'],
#     ['г.',
#      'Проектная',
#      'декларация',
#      'на',
#      'сайте',
#      'www.жк-запад.рф.',
#      'Ставка',
#      'по',
#      'кредиту',
#      'снижена'],
#     ['г',
#      'Пользователем;',
#      'уточнение',
#      '(обновление,',
#      'изменение);',
#      'использование;',
#      'уничтожение;',
#      'обезличивание;',
#      'передача',
#      'по']],
#    [['г.',
#      'Ростов-на-Дону',
#      '8',
#      '(863)',
#      '204-30-31',
#      'г.',
#      'Ростов-на-Дону',
#      'Заказать',
#      'звонок',
#      '<li>'],
#     ['г.',
#      'Проектная',
#      'декларация',
#      'на',
#      'сайте',
#      'www.жк-запад.рф.',
#      'Ставка',
#      'по',
#      'кредиту',
#      'снижена'],
#     ['г',
#      'Пользователем;',
#      'уточнение',
#      '(обновление,',
#      'изменение);',
#      'использование;',
#      'уничтожение;',
#      'обезличивание;',
#      'передача',
#      'по']],
#    [['г.',
#      'Ростов-на-Дону',
#      '8',
#      '(863)',
#      '204-30-31',
#      'г.',
#      'Ростов-на-Дону',
#      'Заказать',
#      'звонок',
#      '<li>'],
#     ['г.',
#      'Проектная',
#      'декларация',
#      'на',
#      'сайте',
#      'www.жк-запад.рф.',
#      'Ставка',
#      'по',
#      'кредиту',
#      'снижена'],
#     ['г',
#      'Пользователем;',
#      'уточнение',
#      '(обновление,',
#      'изменение);',
#      'использование;',
#      'уничтожение;',
#      'обезличивание;',
#      'передача',
#      'по']]]],
#  ['https://astera.su',
#   array(['73832916799'], dtype='<U11'),
#   None,
#   None,
#   None,
#   [[], [], [], [], [], [], [], []]],
#  ['https://asterra.ru',
#   array(['74951523696', '74956426060'], dtype='<U11'),
#   'Rating@Mail.ru',
#   None,
#   None,
#   [['г.',
#     'Балашиха',
#     ',',
#     'мкр.',
#     '1',
#     'Мая,',
#     'д.',
#     '27',
#     'Многоканальный',
#     'телефон:'],
#    [['г.',
#      'Балашиха',
#      ',',
#      'мкр.',
#      '1',
#      'Мая,',
#      'д.',
#      '27',
#      'Многоканальный',
#      'телефон:']],
#    [['г.',
#      'Балашиха',
#      ',',
#      'мкр.',
#      '1',
#      'Мая,',
#      'д.',
#      '27',
#      'Многоканальный',
#      'телефон:']],
#    [['г.',
#      'Балашиха',
#      ',',
#      'мкр.',
#      '1',
#      'Мая,',
#      'д.',
#      '27',
#      'Многоканальный',
#      'телефон:']],
#    [['г.',
#      'Балашиха',
#      ',',
#      'мкр.',
#      '1',
#      'Мая,',
#      'д.',
#      '27',
#      'Многоканальный',
#      'телефон:']],
#    [['г.',
#      'Балашиха',
#      ',',
#      'мкр.',
#      '1',
#      'Мая,',
#      'д.',
#      '27',
#      'Многоканальный',
#      'телефон:']],
#    [['г.',
#      'Балашиха',
#      ',',
#      'мкр.',
#      '1',
#      'Мая,',
#      'д.',
#      '27',
#      'Многоканальный',
#      'телефон:']],
#    [['г.',
#      'Балашиха',
#      ',',
#      'мкр.',
#      '1',
#      'Мая,',
#      'д.',
#      '27',
#      'Многоканальный',
#      'телефон:']],
#    [['г.',
#      'Балашиха',
#      ',',
#      'мкр.',
#      '1',
#      'Мая,',
#      'д.',
#      '27',
#      'Многоканальный',
#      'телефон:']]]],
#  ['https://aston.click',
#   array(['73432222222', '79999999999'], dtype='<U11'),
#   'ekaterinburg@astongroup.ru',
#   ['6658445514\\'],
#   ['1176658089112'],
#   [['г.', 'Екатеринбург,', 'ул.'],
#    [['г.', 'Екатеринбург,', 'ул.']],
#    [['г.', 'Екатеринбург,', 'ул.']],
#    [['г.', 'Екатеринбург,', 'ул.']],
#    [['г.', 'Екатеринбург,', 'ул.']],
#    [['г.', 'Екатеринбург,', 'ул.']],
#    [['г.', 'Екатеринбург,', 'ул.']],
#    [['г.', 'Екатеринбург,', 'ул.']],
#    [['г.', 'Екатеринбург,', 'ул.']]]],
#  ['https://astongroup.ru',
#   array(['3452288160'], dtype='<U10'),
#   'ekaterinburg@astongroup.ru',
#   ['7708316149', '7708316149'],
#   ['1177746427913'],
#   [['г',
#     'Астон.',
#     'Тюмень',
#     'Астон.',
#     'Новосибирск',
#     '+7',
#     '(499)',
#     '550-96-48',
#     'Жилая',
#     'недвижимость'],
#    ['г.',
#     'Москва,',
#     '\\u003Cbr\\u002F\\u003E',
#     'ул.',
#     'Каланчевская,',
#     'дом',
#     '29,',
#     'строение',
#     '2,',
#     'оф.'],
#    [['г',
#      'Астон.',
#      'Тюмень',
#      'Астон.',
#      'Новосибирск',
#      '+7',
#      '(499)',
#      '550-96-48',
#      'Жилая',
#      'недвижимость'],
#     ['г.',
#      'Москва,',
#      '\\u003Cbr\\u002F\\u003E',
#      'ул.',
#      'Каланчевская,',
#      'дом',
#      '29,',
#      'строение',
#      '2,',
#      'оф.']],
#    [['г',
#      'Астон.',
#      'Тюмень',
#      'Астон.',
#      'Новосибирск',
#      '+7',
#      '(499)',
#      '550-96-48',
#      'Жилая',
#      'недвижимость'],
#     ['г.',
#      'Москва,',
#      '\\u003Cbr\\u002F\\u003E',
#      'ул.',
#      'Каланчевская,',
#      'дом',
#      '29,',
#      'строение',
#      '2,',
#      'оф.']],
#    [['г',
#      'Астон.',
#      'Тюмень',
#      'Астон.',
#      'Новосибирск',
#      '+7',
#      '(499)',
#      '550-96-48',
#      'Жилая',
#      'недвижимость'],
#     ['г.',
#      'Москва,',
#      '\\u003Cbr\\u002F\\u003E',
#      'ул.',
#      'Каланчевская,',
#      'дом',
#      '29,',
#      'строение',
#      '2,',
#      'оф.']],
#    [['г',
#      'Астон.',
#      'Тюмень',
#      'Астон.',
#      'Новосибирск',
#      '+7',
#      '(499)',
#      '550-96-48',
#      'Жилая',
#      'недвижимость'],
#     ['г.',
#      'Москва,',
#      '\\u003Cbr\\u002F\\u003E',
#      'ул.',
#      'Каланчевская,',
#      'дом',
#      '29,',
#      'строение',
#      '2,',
#      'оф.']],
#    [['г',
#      'Астон.',
#      'Тюмень',
#      'Астон.',
#      'Новосибирск',
#      '+7',
#      '(499)',
#      '550-96-48',
#      'Жилая',
#      'недвижимость'],
#     ['г.',
#      'Москва,',
#      '\\u003Cbr\\u002F\\u003E',
#      'ул.',
#      'Каланчевская,',
#      'дом',
#      '29,',
#      'строение',
#      '2,',
#      'оф.']],
#    [['г',
#      'Астон.',
#      'Тюмень',
#      'Астон.',
#      'Новосибирск',
#      '+7',
#      '(499)',
#      '550-96-48',
#      'Жилая',
#      'недвижимость'],
#     ['г.',
#      'Москва,',
#      '\\u003Cbr\\u002F\\u003E',
#      'ул.',
#      'Каланчевская,',
#      'дом',
#      '29,',
#      'строение',
#      '2,',
#      'оф.']],
#    [['г',
#      'Астон.',
#      'Тюмень',
#      'Астон.',
#      'Новосибирск',
#      '+7',
#      '(499)',
#      '550-96-48',
#      'Жилая',
#      'недвижимость'],
#     ['г.',
#      'Москва,',
#      '\\u003Cbr\\u002F\\u003E',
#      'ул.',
#      'Каланчевская,',
#      'дом',
#      '29,',
#      'строение',
#      '2,',
#      'оф.']],
#    [['г',
#      'Астон.',
#      'Тюмень',
#      'Астон.',
#      'Новосибирск',
#      '+7',
#      '(499)',
#      '550-96-48',
#      'Жилая',
#      'недвижимость'],
#     ['г.',
#      'Москва,',
#      '\\u003Cbr\\u002F\\u003E',
#      'ул.',
#      'Каланчевская,',
#      'дом',
#      '29,',
#      'строение',
#      '2,',
#      'оф.']]]],
#  ['https://astra02.ru',
#   array(['73472325056', '73472326870', '79177911230', '83472325056'],
#         dtype='<U11'),
#   '2325056@mail.ru',
#   None,
#   None,
#   [['г.',
#     'Уфа,',
#     'ул.',
#     'Ростовская',
#     '18',
#     'Телефоны',
#     'Заявки',
#     'на',
#     'аренду',
#     '+7'],
#    [['г.',
#      'Уфа,',
#      'ул.',
#      'Ростовская',
#      '18',
#      'Телефоны',
#      'Заявки',
#      'на',
#      'аренду',
#      '+7']],
#    [['г.',
#      'Уфа,',
#      'ул.',
#      'Ростовская',
#      '18',
#      'Телефоны',
#      'Заявки',
#      'на',
#      'аренду',
#      '+7']],
#    [['г.',
#      'Уфа,',
#      'ул.',
#      'Ростовская',
#      '18',
#      'Телефоны',
#      'Заявки',
#      'на',
#      'аренду',
#      '+7']],
#    [['г.',
#      'Уфа,',
#      'ул.',
#      'Ростовская',
#      '18',
#      'Телефоны',
#      'Заявки',
#      'на',
#      'аренду',
#      '+7']],
#    [['г.',
#      'Уфа,',
#      'ул.',
#      'Ростовская',
#      '18',
#      'Телефоны',
#      'Заявки',
#      'на',
#      'аренду',
#      '+7']],
#    [['г.',
#      'Уфа,',
#      'ул.',
#      'Ростовская',
#      '18',
#      'Телефоны',
#      'Заявки',
#      'на',
#      'аренду',
#      '+7']],
#    [['г.',
#      'Уфа,',
#      'ул.',
#      'Ростовская',
#      '18',
#      'Телефоны',
#      'Заявки',
#      'на',
#      'аренду',
#      '+7']],
#    [['г.',
#      'Уфа,',
#      'ул.',
#      'Ростовская',
#      '18',
#      'Телефоны',
#      'Заявки',
#      'на',
#      'аренду',
#      '+7']]]],
#  ['https://astraarch.ru',
#   array(['79276646000'], dtype='<U11'),
#   'bnseredin@mail.ru',
#   None,
#   None,
#   [['г.',
#     'Средний',
#     'чек',
#     'на',
#     'проектные',
#     'работы',
#     'от',
#     '4900',
#     'рублей;',
#     'на'],
#    [['г.',
#      'Средний',
#      'чек',
#      'на',
#      'проектные',
#      'работы',
#      'от',
#      '4900',
#      'рублей;',
#      'на']],
#    [['г.',
#      'Средний',
#      'чек',
#      'на',
#      'проектные',
#      'работы',
#      'от',
#      '4900',
#      'рублей;',
#      'на']],
#    [['г.',
#      'Средний',
#      'чек',
#      'на',
#      'проектные',
#      'работы',
#      'от',
#      '4900',
#      'рублей;',
#      'на']],
#    [['г.',
#      'Средний',
#      'чек',
#      'на',
#      'проектные',
#      'работы',
#      'от',
#      '4900',
#      'рублей;',
#      'на']],
#    [['г.',
#      'Средний',
#      'чек',
#      'на',
#      'проектные',
#      'работы',
#      'от',
#      '4900',
#      'рублей;',
#      'на']],
#    [['г.',
#      'Средний',
#      'чек',
#      'на',
#      'проектные',
#      'работы',
#      'от',
#      '4900',
#      'рублей;',
#      'на']],
#    [['г.',
#      'Средний',
#      'чек',
#      'на',
#      'проектные',
#      'работы',
#      'от',
#      '4900',
#      'рублей;',
#      'на']],
#    [['г.',
#      'Средний',
#      'чек',
#      'на',
#      'проектные',
#      'работы',
#      'от',
#      '4900',
#      'рублей;',
#      'на']]]],
#  ['https://atlant-complex.ru',
#   array(['4822631010'], dtype='<U10'),
#   None,
#   None,
#   ['.8355645678836,'],
#   [['г.',
#     'Тверь,',
#     'ул.',
#     '15',
#     'лет',
#     'Октября,',
#     'д.',
#     '52,',
#     'корпус',
#     '1'],
#    [['г.',
#      'Тверь,',
#      'ул.',
#      '15',
#      'лет',
#      'Октября,',
#      'д.',
#      '52,',
#      'корпус',
#      '1']],
#    [['г.',
#      'Тверь,',
#      'ул.',
#      '15',
#      'лет',
#      'Октября,',
#      'д.',
#      '52,',
#      'корпус',
#      '1']],
#    [['г.',
#      'Тверь,',
#      'ул.',
#      '15',
#      'лет',
#      'Октября,',
#      'д.',
#      '52,',
#      'корпус',
#      '1']],
#    [['г.',
#      'Тверь,',
#      'ул.',
#      '15',
#      'лет',
#      'Октября,',
#      'д.',
#      '52,',
#      'корпус',
#      '1']],
#    [['г.',
#      'Тверь,',
#      'ул.',
#      '15',
#      'лет',
#      'Октября,',
#      'д.',
#      '52,',
#      'корпус',
#      '1']],
#    [['г.',
#      'Тверь,',
#      'ул.',
#      '15',
#      'лет',
#      'Октября,',
#      'д.',
#      '52,',
#      'корпус',
#      '1']],
#    [['г.',
#      'Тверь,',
#      'ул.',
#      '15',
#      'лет',
#      'Октября,',
#      'д.',
#      '52,',
#      'корпус',
#      '1']],
#    [['г.',
#      'Тверь,',
#      'ул.',
#      '15',
#      'лет',
#      'Октября,',
#      'д.',
#      '52,',
#      'корпус',
#      '1']]]],
#  ['https://atlas-realty.ru',
#   array(['78624440312', '88002010303', '88624440312', '88624440512'],
#         dtype='<U11'),
#   'fancybox@3.5.7',
#   None,
#   None,
#   [['г.',
#     'Сочи.',
#     'Дом',
#     'утопает',
#     'в',
#     'зелени',
#     'субтропических',
#     'культур.',
#     'По',
#     'соседству'],
#    ['г.',
#     'Сочи',
#     'найти',
#     'именно',
#     'тот',
#     'вариант,',
#     'о',
#     'котором',
#     'мы',
#     'мечтали.'],
#    [['г.',
#      'Сочи.',
#      'Дом',
#      'утопает',
#      'в',
#      'зелени',
#      'субтропических',
#      'культур.',
#      'По',
#      'соседству'],
#     ['г.',
#      'Сочи',
#      'найти',
#      'именно',
#      'тот',
#      'вариант,',
#      'о',
#      'котором',
#      'мы',
#      'мечтали.']],
#    [['г.',
#      'Сочи.',
#      'Дом',
#      'утопает',
#      'в',
#      'зелени',
#      'субтропических',
#      'культур.',
#      'По',
#      'соседству'],
#     ['г.',
#      'Сочи',
#      'найти',
#      'именно',
#      'тот',
#      'вариант,',
#      'о',
#      'котором',
#      'мы',
#      'мечтали.']],
#    [['г.',
#      'Сочи.',
#      'Дом',
#      'утопает',
#      'в',
#      'зелени',
#      'субтропических',
#      'культур.',
#      'По',
#      'соседству'],
#     ['г.',
#      'Сочи',
#      'найти',
#      'именно',
#      'тот',
#      'вариант,',
#      'о',
#      'котором',
#      'мы',
#      'мечтали.']],
#    [['г.',
#      'Сочи.',
#      'Дом',
#      'утопает',
#      'в',
#      'зелени',
#      'субтропических',
#      'культур.',
#      'По',
#      'соседству'],
#     ['г.',
#      'Сочи',
#      'найти',
#      'именно',
#      'тот',
#      'вариант,',
#      'о',
#      'котором',
#      'мы',
#      'мечтали.']],
#    [['г.',
#      'Сочи.',
#      'Дом',
#      'утопает',
#      'в',
#      'зелени',
#      'субтропических',
#      'культур.',
#      'По',
#      'соседству'],
#     ['г.',
#      'Сочи',
#      'найти',
#      'именно',
#      'тот',
#      'вариант,',
#      'о',
#      'котором',
#      'мы',
#      'мечтали.']],
#    [['г.',
#      'Сочи.',
#      'Дом',
#      'утопает',
#      'в',
#      'зелени',
#      'субтропических',
#      'культур.',
#      'По',
#      'соседству'],
#     ['г.',
#      'Сочи',
#      'найти',
#      'именно',
#      'тот',
#      'вариант,',
#      'о',
#      'котором',
#      'мы',
#      'мечтали.']],
#    [['г.',
#      'Сочи.',
#      'Дом',
#      'утопает',
#      'в',
#      'зелени',
#      'субтропических',
#      'культур.',
#      'По',
#      'соседству'],
#     ['г.',
#      'Сочи',
#      'найти',
#      'именно',
#      'тот',
#      'вариант,',
#      'о',
#      'котором',
#      'мы',
#      'мечтали.']],
#    [['г.',
#      'Сочи.',
#      'Дом',
#      'утопает',
#      'в',
#      'зелени',
#      'субтропических',
#      'культур.',
#      'По',
#      'соседству'],
#     ['г.',
#      'Сочи',
#      'найти',
#      'именно',
#      'тот',
#      'вариант,',
#      'о',
#      'котором',
#      'мы',
#      'мечтали.']]]],
#  [None, None, None, None, None, None],
#  ['https://atmosfera32.ru',
#   array(['4832770307'], dtype='<U10'),
#   'info@atmosfera32.ru',
#   None,
#   None,
#   [['г.',
#     'Брянск,',
#     'ул.',
#     'Войстроченко,',
#     'д.',
#     '3',
#     'остановка',
#     '«Улица',
#     'Войстроченко»',
#     '+7'],
#    ['г.',
#     'Брянск',
#     ',',
#     'ул.',
#     'Войстроченко,',
#     'д.',
#     '3',
#     'Социальные',
#     'сети',
#     'Разработано'],
#    [['г.',
#      'Брянск,',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'остановка',
#      '«Улица',
#      'Войстроченко»',
#      '+7'],
#     ['г.',
#      'Брянск',
#      ',',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'Социальные',
#      'сети',
#      'Разработано']],
#    [['г.',
#      'Брянск,',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'остановка',
#      '«Улица',
#      'Войстроченко»',
#      '+7'],
#     ['г.',
#      'Брянск',
#      ',',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'Социальные',
#      'сети',
#      'Разработано']],
#    [['г.',
#      'Брянск,',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'остановка',
#      '«Улица',
#      'Войстроченко»',
#      '+7'],
#     ['г.',
#      'Брянск',
#      ',',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'Социальные',
#      'сети',
#      'Разработано']],
#    [['г.',
#      'Брянск,',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'остановка',
#      '«Улица',
#      'Войстроченко»',
#      '+7'],
#     ['г.',
#      'Брянск',
#      ',',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'Социальные',
#      'сети',
#      'Разработано']],
#    [['г.',
#      'Брянск,',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'остановка',
#      '«Улица',
#      'Войстроченко»',
#      '+7'],
#     ['г.',
#      'Брянск',
#      ',',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'Социальные',
#      'сети',
#      'Разработано']],
#    [['г.',
#      'Брянск,',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'остановка',
#      '«Улица',
#      'Войстроченко»',
#      '+7'],
#     ['г.',
#      'Брянск',
#      ',',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'Социальные',
#      'сети',
#      'Разработано']],
#    [['г.',
#      'Брянск,',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'остановка',
#      '«Улица',
#      'Войстроченко»',
#      '+7'],
#     ['г.',
#      'Брянск',
#      ',',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'Социальные',
#      'сети',
#      'Разработано']],
#    [['г.',
#      'Брянск,',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'остановка',
#      '«Улица',
#      'Войстроченко»',
#      '+7'],
#     ['г.',
#      'Брянск',
#      ',',
#      'ул.',
#      'Войстроченко,',
#      'д.',
#      '3',
#      'Социальные',
#      'сети',
#      'Разработано']]]],
#  ['https://atomstroy.net',
#   array(['73432669393'], dtype='<U11'),
#   None,
#   [':1681392480,',
#    ':1681374095,',
#    ':1680790214,',
#    ':1680177316,',
#    ':1680075825,',
#    ':1679553782,'],
#   None,
#   [[], [], [], [], [], [], [], []]]]

# %%
df = pd.DataFrame(results, columns =['url', 'tel', 'mail', 'inn', 'ogrn', 'address'], dtype = float)
df
# Out:
# /tmp/ipykernel_26531/3801391980.py:1: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   df = pd.DataFrame(results, columns =['url', 'tel', 'mail', 'inn', 'ogrn', 'address'], dtype = float)
#                           url  \
# 0        https://1000sotok.ru
# 1                        None
# 2          https://12sever.ru
# 3         https://1470umto.ru
# 4            https://1lion.ru
# ..                        ...
# 95  https://atlant-complex.ru
# 96    https://atlas-realty.ru
# 97                       None
# 98     https://atmosfera32.ru
# 99      https://atomstroy.net
#
#                                                   tel                 mail  \
# 0   [88125150070, 89013021152, 89013021312, 890130...                 None
# 1                                                None                 None
# 2                            [8362335588, 8362458854]        seversg@bk.ru
# 3                                        [3022217719]     info@1470umto.ru
# 4                          [79788046535, 89788580000]                 None
# ..                                                ...                  ...
# 95                                       [4822631010]                 None
# 96  [78624440312, 88002010303, 88624440312, 886244...       fancybox@3.5.7
# 97                                               None                 None
# 98                                       [4832770307]  info@atmosfera32.ru
# 99                                      [73432669393]                 None
#
#                                                   inn  \
# 0                                                None
# 1                                                None
# 2                [1681765606, 1681765606, 1681765606]
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99  [:1681392480,, :1681374095,, :1680790214,, :16...
#
#                                                  ogrn  \
# 0                                                None
# 1                                                None
# 2   [_1535552722157{, _1538396594893{, _1490364209...
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                  [.8355645678836,]
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
#                                               address
# 0                    [[], [], [], [], [], [], [], []]
# 1                                                None
# 2   [[г., Йошкар-Ола,, ул., Чернякова,, поз., 25, ...
# 3   [[г., Москва,, Очаковское, шоссе,, д., 28, с.1...
# 4   [[г., Алушта, ул., Вл., Хромых,, 29,, 2, эт., ...
# ..                                                ...
# 95  [[г., Тверь,, ул., 15, лет, Октября,, д., 52,,...
# 96  [[г., Сочи., Дом, утопает, в, зелени, субтропи...
# 97                                               None
# 98  [[г., Брянск,, ул., Войстроченко,, д., 3, оста...
# 99                   [[], [], [], [], [], [], [], []]
#
# [100 rows x 6 columns]
